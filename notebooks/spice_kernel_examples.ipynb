# %%
import spiceypy as spice

from planetarypy.spice import (
    datasets,
    download_generic_kernels,
    get_metakernel_and_files,
    list_kernels_for_day,
    load_generic_kernels,
    show_loaded_kernels,
)

# %%
datasets
# Out:
#                                                         path  \
# shorthand
# bc                                               bc/bc_spice
# cassini                    co-s_j_e_v-spice-6-v1.0/cosp_1000
# clementine                    clem1-l-spice-6-v1.0/clsp_1000
# dart                                         dart/dart_spice
# dawn                       dawn-m_a-spice-6-v1.0/dawnsp_1000
# di                               di-c-spice-6-v1.0/disp_1000
# ds1                          ds1-a_c-spice-6-v1.0/ds1sp_1000
# epoxi                      dif-c_e_x-spice-6-v1.0/epxsp_1000
# em16                                         em16/em16_spice
# grail                        grail-l-spice-6-v1.0/grlsp_1000
# hayabusa                       hay-a-spice-6-v1.0/haysp_1000
# insight                                insight/insight_spice
# juno                      jno-j_e_ss-spice-6-v1.0/jnosp_1000
# ladee                                      ladee/ladee_spice
# lro                            lro-l-spice-6-v1.0/lrosp_1000
# maven                                      maven/maven_spice
# opportunity                  mer1-m-spice-6-v1.0/mer1sp_1000
# spirit                       mer2-m-spice-6-v1.0/mer2sp_1000
# messenger                mess-e_v_h-spice-6-v1.0/messsp_1000
# mars2020                             mars2020/mars2020_spice
# mex                          mex-e_m-spice-6-v2.0/mexsp_2000
# mgs                             mgs-m-spice-6-v1.0/mgsp_1000
# ody                             ody-m-spice-6-v1.0/odsp_1000
# mro                            mro-m-spice-6-v1.0/mrosp_1000
# msl                            msl-m-spice-6-v1.0/mslsp_1000
# near                         near-a-spice-6-v1.0/nearsp_1000
# nh                          nh-j_p_ss-spice-6-v1.0/nhsp_1000
# orex                                         orex/orex_spice
# rosetta                ro_rl-e_m_a_c-spice-6-v1.0/rossp_1000
# stardust                        sdu-c-spice-6-v1.0/sdsp_1000
# venus_climate_orbiter                          vco/vco_spice
# vex                          vex-e_v-spice-6-v2.0/vexsp_2000
# vo                          vo1_vo2-m-spice-6-v1.0/vosp_1000
#
#                                        Mission Name  PDS3 or PDS4  \
# shorthand
# bc                                      BepiColombo             4
# cassini                             Cassini Orbiter             3
# clementine                               Clementine             3
# dart                                           DART             4
# dawn                                           DAWN             3
# di                                      Deep Impact             3
# ds1                                    Deep Space 1             3
# epoxi                                         EPOXI             3
# em16                               ExoMars TGO 2016             4
# grail                                         GRAIL             3
# hayabusa                                   Hayabusa             3
# insight                                     InSight             4
# juno                                           JUNO             3
# ladee                                         LADEE             4
# lro                    Lunar Reconnaissance Orbiter             3
# maven                                         MAVEN             4
# opportunity                     MER 1 (Opportunity)             3
# spirit                               MER 2 (Spirit)             3
# messenger                                 MESSENGER             3
# mars2020                                  Mars 2020             4
# mex                                    Mars Express             3
# mgs                            Mars Global Surveyor             3
# ody                                    Mars Odyssey             3
# mro                     Mars Reconnaissance Orbiter             3
# msl                         Mars Science Laboratory             3
# near                                           NEAR             3
# nh                                     New Horizons             3
# orex                                     OSIRIS-REx             4
# rosetta                                     Rosetta             3
# stardust                                   Stardust             3
# venus_climate_orbiter         Venus Climate Orbiter             4
# vex                                   Venus Express             3
# vo                                   Viking Orbiter             3
#
#                        Data Size (GB)  Start Time   Stop Time
# shorthand
# bc                                2.6  2018-10-20  2024-01-01
# cassini                          73.5  1997-10-15  2017-09-15
# clementine                        0.8  1994-01-26  1994-05-07
# dart                             10.1  2021-11-09  2050-01-01
# dawn                             86.4  2007-09-27  2018-10-31
# di                                0.7  2005-01-12  2005-08-09
# ds1                               0.9  1998-10-24  2001-12-18
# epoxi                             1.0  2005-08-23  2011-03-01
# em16                             11.0  2016-03-14  2024-01-01
# grail                             4.3  2011-09-10  2012-12-17
# hayabusa                          0.3  2005-09-11  2005-11-19
# insight                           0.9  2018-05-05  2022-12-15
# juno                             48.9  2011-08-05  2023-07-31
# ladee                             0.6  2013-09-07  2050-01-01
# lro                             627.5  2009-06-18  2023-12-15
# maven                            57.6  2013-11-18  2024-01-01
# opportunity                       4.1  2003-07-07  2018-06-10
# spirit                            2.6  2003-06-10  2010-05-03
# messenger                        44.8  2004-08-03  2015-04-30
# mars2020                          0.7  2020-07-30  2024-01-02
# mex                              11.0  2003-06-02  2023-12-31
# mgs                              15.4  1996-11-06  2006-11-02
# ody                              35.8  2001-04-07  2023-10-01
# mro                             329.2  2005-08-12  2024-01-01
# msl                               0.7  2011-11-26  2023-11-06
# near                              2.4  1996-05-30  2001-02-28
# nh                                1.7  2006-01-19  2022-06-01
# orex                            424.7  2016-09-08  2023-10-02
# rosetta                           5.9  2004-03-02  2017-01-01
# stardust                          1.9  1999-02-07  2011-05-01
# venus_climate_orbiter             2.0  2010-05-21  2024-01-01
# vex                               5.0  2005-11-09  2015-02-06
# vo                                0.1  1976-06-16  1980-07-30

# %%
list_kernels_for_day?
# Out:
# Signature: list_kernels_for_day(mission: str, start: str, stop: str = '') -> list
# Docstring:
# List all kernels for a given time range of a mission.
#
# Parameters
# ----------
# mission : str
#     Mission shorthand in datasets dataframe.
# start : str
#     Start time in either ISO or yyyy-jjj format.
# stop : str, optional
#     Stop time in either ISO or yyyy-jjj format. Defaults to None.
# File:      ~/Dropbox/src/planetarypy/src/planetarypy/spice/archived_kernels.py
# Type:      function

# %%
list_kernels_for_day("messenger", "2011-01-01")
# Out:
# ['ck/msgr_1101_v02.bc',
#  'ck/msgr_mdis_gm040819_150430v1.bc',
#  'fk/msgr_dyn_v600.tf',
#  'fk/msgr_v231.tf',
#  'ik/msgr_epps_v100.ti',
#  'ik/msgr_grns_v110.ti',
#  'ik/msgr_mag_v021.ti',
#  'ik/msgr_mascs_v100.ti',
#  'ik/msgr_mdis_v160.ti',
#  'ik/msgr_mla_v010.ti',
#  'ik/msgr_rs_v111.ti',
#  'ik/msgr_xrs_v001.ti',
#  'lsk/naif0011.tls',
#  'pck/pck00010_msgr_v23.tpc',
#  'sclk/messenger_2548.tsc',
#  'spk/msgr_040803_150430_150430_od431sc_2.bsp',
#  'spk/msgr_antenna_v000.bsp']

# %%
mk_path = get_metakernel_and_files(
    mission="cassini", start="2015-01-01", stop="2015-01-02"
)
# Out:
# Kernels downloaded:   0%|          | 0/31 [00:00<?, ?it/s]

# %%
spice.furnsh(mk_path.as_posix())

# %%
show_loaded_kernels()
# Out:
# The loaded files are:
# (paths relative to kernels.KERNEL_STORAGE)
#
# Position: 0
# Path cassini/cas_2015_v09_150101_150102.tm
# Type: META
# Source:
# Handle: 0
# Position: 1
# Path cassini/lsk/naif0012.tls
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 2
# Path cassini/pck/pck00010.tpc
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 3
# Path cassini/pck/enceladus_ssd_230702_v1.tpc
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 4
# Path cassini/fk/cas_rocks_v18.tf
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 5
# Path cassini/fk/cas_mimi_v202.tf
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 6
# Path cassini/fk/cas_dyn_v03.tf
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 7
# Path cassini/fk/cas_v43.tf
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 8
# Path cassini/ik/cas_caps_v03.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 9
# Path cassini/ik/cas_cda_v01.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 10
# Path cassini/ik/cas_cirs_v10.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 11
# Path cassini/ik/cas_inms_v02.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 12
# Path cassini/ik/cas_iss_v10.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 13
# Path cassini/ik/cas_mag_v01.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 14
# Path cassini/ik/cas_mimi_v11.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 15
# Path cassini/ik/cas_radar_v11.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 16
# Path cassini/ik/cas_rpws_v01.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 17
# Path cassini/ik/cas_rss_v03.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 18
# Path cassini/ik/cas_sru_v02.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 19
# Path cassini/ik/cas_uvis_v07.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 20
# Path cassini/ik/cas_vims_v06.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 21
# Path cassini/sclk/cas00172.tsc
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 22
# Path cassini/spk/180927AP_RE_90165_18018.bsp
# Type: SPK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 1
# Position: 23
# Path cassini/spk/140809BP_IRRE_00256_25017.bsp
# Type: SPK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 2
# Position: 24
# Path cassini/spk/sat427.bsp
# Type: SPK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 3
# Position: 25
# Path cassini/spk/200128RU_SCPSE_14365_15033.bsp
# Type: SPK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 4
# Position: 26
# Path cassini/ck/15001_16001pa_gapfill_v14.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 5
# Position: 27
# Path cassini/ck/14351_15052py_as_flown.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 6
# Position: 28
# Path cassini/ck/14363_15003ra.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 7
# Position: 29
# Path cassini/ck/cas_cda_20170627.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 8
# Position: 30
# Path cassini/ck/cas_lemms_05109_20001_v2.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 9
# Position: 31
# Path cassini/dsk/cas_enceladus_ssd_spc_0128icq_v1.bds
# Type: DSK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 10
# Position: 32
# Path generic/lsk/naif0012.tls
# Type: TEXT
# Source:
# Handle: 0
# Position: 33
# Path generic/pck/pck00010.tpc
# Type: TEXT
# Source:
# Handle: 0
# Position: 34
# Path generic/pck/de-403-masses.tpc
# Type: TEXT
# Source:
# Handle: 0
# Position: 35
# Path generic/spk/planets/de430.bsp
# Type: SPK
# Source:
# Handle: 11
# Position: 36
# Path generic/spk/satellites/mar097.bsp
# Type: SPK
# Source:
# Handle: 12
# Position: 37
# Path cassini/cas_2015_v09_150101_150102.tm
# Type: META
# Source:
# Handle: 0
# Position: 38
# Path cassini/lsk/naif0012.tls
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 39
# Path cassini/pck/pck00010.tpc
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 40
# Path cassini/pck/enceladus_ssd_230702_v1.tpc
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 41
# Path cassini/fk/cas_rocks_v18.tf
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 42
# Path cassini/fk/cas_mimi_v202.tf
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 43
# Path cassini/fk/cas_dyn_v03.tf
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 44
# Path cassini/fk/cas_v43.tf
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 45
# Path cassini/ik/cas_caps_v03.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 46
# Path cassini/ik/cas_cda_v01.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 47
# Path cassini/ik/cas_cirs_v10.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 48
# Path cassini/ik/cas_inms_v02.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 49
# Path cassini/ik/cas_iss_v10.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 50
# Path cassini/ik/cas_mag_v01.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 51
# Path cassini/ik/cas_mimi_v11.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 52
# Path cassini/ik/cas_radar_v11.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 53
# Path cassini/ik/cas_rpws_v01.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 54
# Path cassini/ik/cas_rss_v03.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 55
# Path cassini/ik/cas_sru_v02.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 56
# Path cassini/ik/cas_uvis_v07.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 57
# Path cassini/ik/cas_vims_v06.ti
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 58
# Path cassini/sclk/cas00172.tsc
# Type: TEXT
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 0
# Position: 59
# Path cassini/spk/180927AP_RE_90165_18018.bsp
# Type: SPK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 1
# Position: 60
# Path cassini/spk/140809BP_IRRE_00256_25017.bsp
# Type: SPK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 2
# Position: 61
# Path cassini/spk/sat427.bsp
# Type: SPK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 3
# Position: 62
# Path cassini/spk/200128RU_SCPSE_14365_15033.bsp
# Type: SPK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 4
# Position: 63
# Path cassini/ck/15001_16001pa_gapfill_v14.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 5
# Position: 64
# Path cassini/ck/14351_15052py_as_flown.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 6
# Position: 65
# Path cassini/ck/14363_15003ra.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 7
# Position: 66
# Path cassini/ck/cas_cda_20170627.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 8
# Position: 67
# Path cassini/ck/cas_lemms_05109_20001_v2.bc
# Type: CK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 9
# Position: 68
# Path cassini/dsk/cas_enceladus_ssd_spc_0128icq_v1.bds
# Type: DSK
# Source: /Users/maye/planetarypy_data/spice_kernels/cassini/cas_2015_v09_150101_150102.tm
# Handle: 10
# ['cassini/cas_2015_v09_150101_150102.tm',
#  'cassini/lsk/naif0012.tls',
#  'cassini/pck/pck00010.tpc',
#  'cassini/pck/enceladus_ssd_230702_v1.tpc',
#  'cassini/fk/cas_rocks_v18.tf',
#  'cassini/fk/cas_mimi_v202.tf',
#  'cassini/fk/cas_dyn_v03.tf',
#  'cassini/fk/cas_v43.tf',
#  'cassini/ik/cas_caps_v03.ti',
#  'cassini/ik/cas_cda_v01.ti',
#  'cassini/ik/cas_cirs_v10.ti',
#  'cassini/ik/cas_inms_v02.ti',
#  'cassini/ik/cas_iss_v10.ti',
#  'cassini/ik/cas_mag_v01.ti',
#  'cassini/ik/cas_mimi_v11.ti',
#  'cassini/ik/cas_radar_v11.ti',
#  'cassini/ik/cas_rpws_v01.ti',
#  'cassini/ik/cas_rss_v03.ti',
#  'cassini/ik/cas_sru_v02.ti',
#  'cassini/ik/cas_uvis_v07.ti',
#  'cassini/ik/cas_vims_v06.ti',
#  'cassini/sclk/cas00172.tsc',
#  'cassini/spk/180927AP_RE_90165_18018.bsp',
#  'cassini/spk/140809BP_IRRE_00256_25017.bsp',
#  'cassini/spk/sat427.bsp',
#  'cassini/spk/200128RU_SCPSE_14365_15033.bsp',
#  'cassini/ck/15001_16001pa_gapfill_v14.bc',
#  'cassini/ck/14351_15052py_as_flown.bc',
#  'cassini/ck/14363_15003ra.bc',
#  'cassini/ck/cas_cda_20170627.bc',
#  'cassini/ck/cas_lemms_05109_20001_v2.bc',
#  'cassini/dsk/cas_enceladus_ssd_spc_0128icq_v1.bds',
#  'generic/lsk/naif0012.tls',
#  'generic/pck/pck00010.tpc',
#  'generic/pck/de-403-masses.tpc',
#  'generic/spk/planets/de430.bsp',
#  'generic/spk/satellites/mar097.bsp',
#  'cassini/cas_2015_v09_150101_150102.tm',
#  'cassini/lsk/naif0012.tls',
#  'cassini/pck/pck00010.tpc',
#  'cassini/pck/enceladus_ssd_230702_v1.tpc',
#  'cassini/fk/cas_rocks_v18.tf',
#  'cassini/fk/cas_mimi_v202.tf',
#  'cassini/fk/cas_dyn_v03.tf',
#  'cassini/fk/cas_v43.tf',
#  'cassini/ik/cas_caps_v03.ti',
#  'cassini/ik/cas_cda_v01.ti',
#  'cassini/ik/cas_cirs_v10.ti',
#  'cassini/ik/cas_inms_v02.ti',
#  'cassini/ik/cas_iss_v10.ti',
#  'cassini/ik/cas_mag_v01.ti',
#  'cassini/ik/cas_mimi_v11.ti',
#  'cassini/ik/cas_radar_v11.ti',
#  'cassini/ik/cas_rpws_v01.ti',
#  'cassini/ik/cas_rss_v03.ti',
#  'cassini/ik/cas_sru_v02.ti',
#  'cassini/ik/cas_uvis_v07.ti',
#  'cassini/ik/cas_vims_v06.ti',
#  'cassini/sclk/cas00172.tsc',
#  'cassini/spk/180927AP_RE_90165_18018.bsp',
#  'cassini/spk/140809BP_IRRE_00256_25017.bsp',
#  'cassini/spk/sat427.bsp',
#  'cassini/spk/200128RU_SCPSE_14365_15033.bsp',
#  'cassini/ck/15001_16001pa_gapfill_v14.bc',
#  'cassini/ck/14351_15052py_as_flown.bc',
#  'cassini/ck/14363_15003ra.bc',
#  'cassini/ck/cas_cda_20170627.bc',
#  'cassini/ck/cas_lemms_05109_20001_v2.bc',
#  'cassini/dsk/cas_enceladus_ssd_spc_0128icq_v1.bds']

# %%
load_generic_kernels()  # uses below download_generic_kernels if any kernel from generic list is missing.

# %%
download_generic_kernels()
# Out:
# naif0012.tls already downloaded. Use `overwrite=True` to download again.
# pck00010.tpc already downloaded. Use `overwrite=True` to download again.
# de-403-masses.tpc already downloaded. Use `overwrite=True` to download again.
# de430.bsp already downloaded. Use `overwrite=True` to download again.
# mar097.bsp already downloaded. Use `overwrite=True` to download again.
