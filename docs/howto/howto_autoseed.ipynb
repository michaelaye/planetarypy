# %% [markdown]
# # How-To: Automize the `autoseed` ISIS command
#
# Using `planetarypy.isis.autoseed` module, you can script the `autoseed` command in ISIS to automate the process of generating seed points for image matching or coregistration.
#
# This brief How-To will walk you through the minimal steps to use the `autoseed` module.

# %%
from planetarypy.isis import autoseed
